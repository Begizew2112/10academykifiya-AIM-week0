# %%
import pandas as pd

# Load summary statistics from CSV files
summary_region1 = pd.read_csv('summary_region1.csv')
summary_region2 = pd.read_csv('summary_region2.csv')
summary_region3 = pd.read_csv('summary_region3.csv')

# %%
# Display the summaries for verification
print("Summary Statistics for Region 1:")
summary_region1
# Out:
# Summary Statistics for Region 1:
#   Unnamed: 0            GHI            DNI            DHI           Tamb
# 0      count  516143.000000  516143.000000  516143.000000  516143.000000
# 1       mean     238.574677     164.865746     115.784792      28.177203
# 2        std     327.963230     259.576014     156.808709       5.942777
# 3        min       0.000000       0.000000       0.000000      11.000000
# 4        25%       0.000000       0.000000       0.000000      24.200000
# 5        50%       0.800000       0.000000       0.600000      28.000000
# 6        75%     472.100000     305.300000     214.000000      32.300000
# 7        max    1268.000000     952.300000     759.200000      43.800000

# %%
print("\nSummary Statistics for Region 2:")
summary_region2
# Out:
# Summary Statistics for Region 2:
#   Unnamed: 0            GHI            DNI            DHI           Tamb
# 0      count  471407.000000  471407.000000  471407.000000  471407.000000
# 1       mean     135.392770      66.167320      94.002775      25.725039
# 2        std     211.917706     152.746171     143.415480       4.148144
# 3        min       0.000000       0.000000       0.000000      12.300000
# 4        25%       0.000000       0.000000       0.000000      23.000000
# 5        50%       0.000000       0.000000       0.000000      24.700000
# 6        75%     233.200000       8.800000     171.400000      28.200000
# 7        max    1015.000000     891.000000     738.800000      39.900000

# %%
print("\nSummary Statistics for Region 3:")
summary_region3
# Out:
# Summary Statistics for Region 3:
#   Unnamed: 0            GHI            DNI            DHI           Tamb
# 0      count  482310.000000  482310.000000  482310.000000  482310.000000
# 1       mean     205.482933     131.878610     106.192506      27.642156
# 2        std     305.007986     234.113189     151.312985       4.804774
# 3        min       0.000000       0.000000       0.000000      14.900000
# 4        25%       0.000000       0.000000       0.000000      24.000000
# 5        50%       0.000000       0.000000       0.000000      27.000000
# 6        75%     363.800000     171.400000     194.500000      31.000000
# 7        max    1169.000000     989.800000     805.700000      41.400000

# %%
import matplotlib.pyplot as plt

# Plot a bar chart for mean values of GHI across all regions
combined_summary.loc['mean'][['Region 1_GHI', 'Region 2_GHI', 'Region 3_GHI']].plot(kind='bar')
plt.title('Mean GHI Comparison Across Regions')
plt.ylabel('Mean GHI')
plt.show()

# Similarly, plot for DNI, DHI, and Tamb
combined_summary.loc['mean'][['Region 1_DNI', 'Region 2_DNI', 'Region 3_DNI']].plot(kind='bar')
plt.title('Mean DNI Comparison Across Regions')
plt.ylabel('Mean DNI')
plt.show()

combined_summary.loc['mean'][['Region 1_DHI', 'Region 2_DHI', 'Region 3_DHI']].plot(kind='bar')
plt.title('Mean DHI Comparison Across Regions')
plt.ylabel('Mean DHI')
plt.show()

combined_summary.loc['mean'][['Region 1_Tamb', 'Region 2_Tamb', 'Region 3_Tamb']].plot(kind='bar')
plt.title('Mean Temperature Comparison Across Regions')
plt.ylabel('Mean Temperature (Tamb)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\853438154.py in <module>
#       2
#       3 # Plot a bar chart for mean values of GHI across all regions
# ----> 4 combined_summary.loc['mean'][['Region 1_GHI', 'Region 2_GHI', 'Region 3_GHI']].plot(kind='bar')
#       5 plt.title('Mean GHI Comparison Across Regions')
#       6 plt.ylabel('Mean GHI')
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
# ...

# %%
# Print the index of the combined_summary DataFrame
print(combined_summary.index)
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
# Drop unnamed columns
summary_region1 = summary_region1.loc[:, ~summary_region1.columns.str.contains('^Unnamed')]
summary_region2 = summary_region2.loc[:, ~summary_region2.columns.str.contains('^Unnamed')]
summary_region3 = summary_region3.loc[:, ~summary_region3.columns.str.contains('^Unnamed')]

# %%
# Concatenate summary statistics with multi-index for regions
combined_summary = pd.concat([summary_region1, summary_region2, summary_region3], axis=1, keys=['Region 1', 'Region 2', 'Region 3'])
combined_summary
# Out:
#         Region 1                                                    Region 2  \
#              GHI            DNI            DHI           Tamb            GHI
# 0  516143.000000  516143.000000  516143.000000  516143.000000  471407.000000
# 1     238.574677     164.865746     115.784792      28.177203     135.392770
# 2     327.963230     259.576014     156.808709       5.942777     211.917706
# 3       0.000000       0.000000       0.000000      11.000000       0.000000
# 4       0.000000       0.000000       0.000000      24.200000       0.000000
# 5       0.800000       0.000000       0.600000      28.000000       0.000000
# 6     472.100000     305.300000     214.000000      32.300000     233.200000
# 7    1268.000000     952.300000     759.200000      43.800000    1015.000000
#
#                                                      Region 3                 \
#              DNI            DHI           Tamb            GHI            DNI
# ...

# %%
# Print the combined summary
print(combined_summary)

# Save the combined summary to a CSV file
combined_summary.to_csv('combined_summary_statistics.csv', index=False)
# Out:
#     Region 1_GHI   Region 1_DNI   Region 1_DHI  Region 1_Tamb   Region 2_GHI  \
# 0  516143.000000  516143.000000  516143.000000  516143.000000  471407.000000
# 1     238.574677     164.865746     115.784792      28.177203     135.392770
# 2     327.963230     259.576014     156.808709       5.942777     211.917706
# 3       0.000000       0.000000       0.000000      11.000000       0.000000
# 4       0.000000       0.000000       0.000000      24.200000       0.000000
# 5       0.800000       0.000000       0.600000      28.000000       0.000000
# 6     472.100000     305.300000     214.000000      32.300000     233.200000
# 7    1268.000000     952.300000     759.200000      43.800000    1015.000000
#
#     Region 2_DNI   Region 2_DHI  Region 2_Tamb   Region 3_GHI   Region 3_DNI  \
# 0  471407.000000  471407.000000  471407.000000  482310.000000  482310.000000
# 1      66.167320      94.002775      25.725039     205.482933     131.878610
# ...

# %%
import matplotlib.pyplot as plt

# Plot a bar chart for mean values of GHI across all regions
combined_summary.loc['mean'][['Region 1_GHI', 'Region 2_GHI', 'Region 3_GHI']].plot(kind='bar')
plt.title('Mean GHI Comparison Across Regions')
plt.ylabel('Mean GHI')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\2920830763.py in <module>
#       2
#       3 # Plot a bar chart for mean values of GHI across all regions
# ----> 4 combined_summary.loc['mean'][['Region 1_GHI', 'Region 2_GHI', 'Region 3_GHI']].plot(kind='bar')
#       5 plt.title('Mean GHI Comparison Across Regions')
#       6 plt.ylabel('Mean GHI')
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
# ...

# %%
import matplotlib.pyplot as plt

# Plot a bar chart for mean values of GHI across all regions
combined_summary.loc['mean'][['Region 1_GHI', 'Region 2_GHI', 'Region 3_GHI']].plot(kind='bar')
plt.title('Mean GHI Comparison Across Regions')
plt.ylabel('Mean GHI')
plt.show()

# Similarly, plot for DNI, DHI, and Tamb
combined_summary.loc['mean'][['Region 1_DNI', 'Region 2_DNI', 'Region 3_DNI']].plot(kind='bar')
plt.title('Mean DNI Comparison Across Regions')
plt.ylabel('Mean DNI')
plt.show()

combined_summary.loc['mean'][['Region 1_DHI', 'Region 2_DHI', 'Region 3_DHI']].plot(kind='bar')
plt.title('Mean DHI Comparison Across Regions')
plt.ylabel('Mean DHI')
plt.show()

combined_summary.loc['mean'][['Region 1_Tamb', 'Region 2_Tamb', 'Region 3_Tamb']].plot(kind='bar')
plt.title('Mean Temperature Comparison Across Regions')
plt.ylabel('Mean Temperature (Tamb)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\853438154.py in <module>
#       2
#       3 # Plot a bar chart for mean values of GHI across all regions
# ----> 4 combined_summary.loc['mean'][['Region 1_GHI', 'Region 2_GHI', 'Region 3_GHI']].plot(kind='bar')
#       5 plt.title('Mean GHI Comparison Across Regions')
#       6 plt.ylabel('Mean GHI')
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1203         # fall thru to straight lookup
# ...

# %%
# Concatenate summary statistics with multi-index for regions
combined_summary = pd.concat([summary_region1, summary_region2, summary_region3], axis=1, keys=['Region 1', 'Region 2', 'Region 3'])

# %%
import pandas as pd

# Load your data
df_region1 = pd.read_csv('path_to_region1_data.csv')
df_region2 = pd.read_csv('path_to_region2_data.csv')
df_region3 = pd.read_csv('path_to_region3_data.csv')

# Drop unnamed columns
df_region1 = df_region1.loc[:, ~df_region1.columns.str.contains('^Unnamed')]
df_region2 = df_region2.loc[:, ~df_region2.columns.str.contains('^Unnamed')]
df_region3 = df_region3.loc[:, ~df_region3.columns.str.contains('^Unnamed')]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\373874432.py in <module>
#       2
#       3 # Load your data
# ----> 4 df_region1 = pd.read_csv('path_to_region1_data.csv')
#       5 df_region2 = pd.read_csv('path_to_region2_data.csv')
#       6 df_region3 = pd.read_csv('path_to_region3_data.csv')
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
combined_summary.columns = [
    'Region 1_GHI', 'Region 1_DNI', 'Region 1_DHI', 'Region 1_Tamb',
    'Region 2_GHI', 'Region 2_DNI', 'Region 2_DHI', 'Region 2_Tamb',
    'Region 3_GHI', 'Region 3_DNI', 'Region 3_DHI', 'Region 3_Tamb'
]

# Ensure the number of new names matches the number of columns in combined_summary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\1379717288.py in <module>
# ----> 1 combined_summary.columns = [
#       2     'Region 1_GHI', 'Region 1_DNI', 'Region 1_DHI', 'Region 1_Tamb',
#       3     'Region 2_GHI', 'Region 2_DNI', 'Region 2_DHI', 'Region 2_Tamb',
#       4     'Region 3_GHI', 'Region 3_DNI', 'Region 3_DHI', 'Region 3_Tamb'
#       5 ]
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\221594888.py in <module>
#       2 combined_summary = pd.concat([summary_region1, summary_region2, summary_region3], axis=1)
#       3
# ----> 4 combined_summary.columns = ['Region 1_GHI', 'Region 1_DNI', 'Region 1_DHI', 'Region 1_Tamb',
#       5                             'Region 2_GHI', 'Region 2_DNI', 'Region 2_DHI', 'Region 2_Tamb',
#       6                             'Region 3_GHI', 'Region 3_DNI', 'Region 3_DHI', 'Region 3_Tamb']
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ...

# %%
# Use 'inner' join to concatenate only common columns across all summaries
combined_summary = pd.concat([summary_region1, summary_region2, summary_region3], axis=1, join='inner')

# OR

# Use 'outer' join to include all columns, filling missing data with NaN
combined_summary = pd.concat([summary_region1, summary_region2, summary_region3], axis=1, join='outer')

# %%
# Combine the summary statistics into a single DataFrame
combined_summary = pd.concat([summary_region1, summary_region2, summary_region3], axis=1)

combined_summary.columns = ['Region 1_GHI', 'Region 1_DNI', 'Region 1_DHI', 'Region 1_Tamb',
                            'Region 2_GHI', 'Region 2_DNI', 'Region 2_DHI', 'Region 2_Tamb',
                            'Region 3_GHI', 'Region 3_DNI', 'Region 3_DHI', 'Region 3_Tamb']

# Display the combined summary for comparison
print("\nCombined Summary Statistics:")
combined_summary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6700\221594888.py in <module>
#       2 combined_summary = pd.concat([summary_region1, summary_region2, summary_region3], axis=1)
#       3
# ----> 4 combined_summary.columns = ['Region 1_GHI', 'Region 1_DNI', 'Region 1_DHI', 'Region 1_Tamb',
#       5                             'Region 2_GHI', 'Region 2_DNI', 'Region 2_DHI', 'Region 2_Tamb',
#       6                             'Region 3_GHI', 'Region 3_DNI', 'Region 3_DHI', 'Region 3_Tamb']
#
# c:\Users\Yibabe\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ...
